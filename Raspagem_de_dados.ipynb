# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from io import StringIO

# %%
url = "https://investidor10.com.br/fiis/rankings/maior-dividend-yield/"
headers = {"user-agent":"Mozilla/5.0"}
resposta = requests.get(url, headers=headers)
soup = BeautifulSoup(resposta.content, 'html.parser')
tabela = soup.find_all(name="table")
tabelas_df = [pd.read_html(StringIO(str(tab)))[0] for tab in tabela]
maior_DY = tabelas_df[0]
maior_DY
# Out:
#     Unnamed: 0  DY Atual  P/VP Liquidez Diária Patrimônio Líquido  \
# 0       BBFI11     51.45  0.41      603,75 Mil     196,39 Milhões
# 1       BDIV11     25.59  1.14      980,00 Mil        1,14 Bilhão
# 2       GCRA11     18.94  0.68      232,39 Mil     151,35 Milhões
# 3       BLCA11     18.41  0.83      206,46 Mil     192,43 Milhões
# 4       AAZQ11     18.27  0.87     1,51 Milhão     208,64 Milhões
# ..         ...       ...   ...             ...                ...
# 115     VTLT11     11.45  0.85      118,70 Mil     238,60 Milhões
# 116     VINO11     11.43  0.57     1,20 Milhão     890,50 Milhões
# 117     KCRE11     11.40  0.98      252,65 Mil     348,26 Milhões
# 118     HREC11     11.35  0.97      338,52 Mil     460,06 Milhões
# 119     GARE11     11.34  0.97    4,94 Milhões        1,18 Bilhão
#
#      Var. 12 Meses    Tipo de Fundo  \
# 0         6.358217  Fundo de Tijolo
# 1        32.203944            Outro
# 2       -24.597439            Outro
# 3        -8.690465      Fundo misto
# 4        -4.779874            Outro
# ..             ...              ...
# 115       7.965506  Fundo de Tijolo
# 116     -28.421053  Fundo de Tijolo
# 117       8.209806   Fundo de papel
# 118      16.219839   Fundo de papel
# 119      10.797546  Fundo de Tijolo
#
#                                           Segmento
# 0                               Lajes Corporativas
# 1    Fundo de Investimentos em Participações (FIP)
# 2                                          Fiagros
# 3                               Lajes Corporativas
# 4                                          Fiagros
# ..                                             ...
# 115                Logístico / Indústria / Galpões
# 116                             Lajes Corporativas
# 117                  Títulos e Valores Mobiliários
# 118                  Títulos e Valores Mobiliários
# 119                                        Híbrido
#
# [120 rows x 8 columns]
